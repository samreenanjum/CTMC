# %%
#Read the files

'''
from TrackDataCache import TrackDataCache
import sys

tdc = TrackDataCache()
gtPath = 'gt.txt'
#resPath = '3T3-run02.txt'
resPath = 'A-10-run04.txt'
tdc.calculate(gtPath, resPath)
'''
# Out:
# "\nfrom TrackDataCache import TrackDataCache\nimport sys\n\ntdc = TrackDataCache()\ngtPath = 'gt.txt'\n#resPath = '3T3-run02.txt'\nresPath = 'A-10-run04.txt'\ntdc.calculate(gtPath, resPath)\n"

# %%
list = [1,3,4,5]
list[1]
# Out:
# 3

# %%
from TrackDataCache import TrackDataCache
import sys
from Tra import TRA

tratest = TRA()
gtPath = 'data/3T3-run04/gt.txt'
resPath = '3T3-run02.txt'
resPath = 'data/3T3-run04/3T3-run04.txt'
tratest.calculate(gtPath, resPath)
# Out:
# 45
# [                                                                        ]   0%
# size of gt = (20565, 7)
# size of res = (22219, 7)
# 1
# 2160
# 2160
# [========================================================================] 100%
# aogm: = 10.0, penalty.fn = 10.0
# aogm: = 11.0, penalty.fp = 1.0
# aogm: = 21.0, penalty.fn = 10.0
# aogm: = 22.0, penalty.fp = 1.0
# aogm: = 32.0, penalty.fn = 10.0
# aogm: = 33.0, penalty.fp = 1.0
# aogm: = 43.0, penalty.fn = 10.0
# aogm: = 44.0, penalty.fp = 1.0
# aogm: = 54.0, penalty.fn = 10.0
# aogm: = 55.0, penalty.fp = 1.0
# aogm: = 65.0, penalty.fn = 10.0
# aogm: = 66.0, penalty.fp = 1.0
# aogm: = 76.0, penalty.fn = 10.0
# aogm: = 77.0, penalty.fp = 1.0
# aogm: = 87.0, penalty.fn = 10.0
# aogm: = 88.0, penalty.fp = 1.0
# aogm: = 98.0, penalty.fn = 10.0
# aogm: = 99.0, penalty.fp = 1.0
# aogm: = 109.0, penalty.fn = 10.0
# aogm: = 110.0, penalty.fp = 1.0
# aogm: = 120.0, penalty.fn = 10.0
# aogm: = 121.0, penalty.fp = 1.0
# ...

# %%
import numpy
parent = [False] #numpy.ones((1,0), dtype=bool)

parent[0] = True
parent[0] = False
parent[0]
# Out:
# False
